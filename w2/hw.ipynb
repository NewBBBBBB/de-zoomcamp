# %% [markdown]
# 1. A

# %% [markdown]
# 2. B

# %% [markdown]
# 3. B

# %% [markdown]
# SELECT
#   COUNT(*) AS total_rows_2020
# FROM `iron-figure-312018.zoomcamp.yellow_tripdata`
# WHERE filename LIKE 'yellow_tripdata_2020-%';

# %%
from IPython.display import Image, display
display(Image(filename="image3.png"))

# %% [markdown]
# 4. C

# %% [markdown]
# SELECT
#   COUNT(*) AS total_rows_2020
# FROM `iron-figure-312018.zoomcamp.green_tripdata`
# WHERE filename LIKE 'green_tripdata_2020-%';

# %%
from IPython.display import Image, display
display(Image(filename="Screenshot 2026-02-04 at 5.19.35 PM.png"))

# %% [markdown]
# 5. C

# %%
display(Image(filename="Screenshot 2026-02-04 at 4.54.24 PM.png"))

# %% [markdown]
# 6. B
