# %% [markdown]
# 1. C

# %%
from IPython.display import Image, display
display(Image(filename="Screenshot 2026-02-06 at 4.06.36 PM.png"))

# %% [markdown]
# 2. B

# %%
display(Image(filename="Screenshot 2026-02-06 at 4.09.54 PM.png"))

# %% [markdown]
# 3. A

# %% [markdown]
# 4. D

# %%
from IPython.display import Image, display
display(Image(filename="Screenshot 2026-02-06 at 4.38.27 PM.png"))

# %% [markdown]
# 5. A

# %% [markdown]
# 6. B

# %%
from IPython.display import Image, display
display(Image(filename="Screenshot 2026-02-06 at 4.53.49 PM.png"))

# %%
from IPython.display import Image, display
display(Image(filename="Screenshot 2026-02-06 at 4.53.55 PM.png"))

# %% [markdown]
# 7. C

# %% [markdown]
# 8. B
